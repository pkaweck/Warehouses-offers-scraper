# %% [markdown]
# ***Scraper dla ofert terenów pod magazyny***

# %% [markdown]
# *Zadanie to podzielić scrapery na hale oraz tereny*

# %%
import pandas as pd
import numpy as np
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_html("https://baza.paih.gov.pl/offer/detail/30-428")

# %%
#Kod do sprawdzania czy jest do kontaktu itd. bo nie łapie jako długość tylko ma dwie opcje
def sprawdzenie(zmienna):
    if zmienna == 69:
        zmienna = 69
    elif zmienna == 3:

        zmienna = 3

    elif zmienna == 4:

        zmienna = 4

    elif zmienna == 5:

        zmienna = 5

    elif zmienna == 6:
          zmienna = 6

    elif zmienna == 7:
          zmienna = 7
    elif zmienna == 8:
          zmienna = 8

    elif zmienna == 9:
          zmienna = 9

    elif zmienna == 10:
          zmienna = 10

    elif zmienna == 11:
          zmienna = 11

    elif zmienna== 12:
          zmienna = 12

    elif zmienna == 13:

          zmienna = 13
    elif zmienna == 14:
          zmienna = 14

    elif zmienna == 15:
          zmienna = 15

    elif zmienna == 16:
          zmienna = 16


    elif zmienna == 17:
          zmienna = 17


    elif zmienna == 19:
          zmienna = 19


    elif zmienna == 20:
          zmienna = 20

    elif zmienna == 21:

          zmienna = 21

    elif zmienna == 22:
          zmienna = 22

    elif zmienna == 23:
          zmienna = 23


    elif zmienna == 24:
          zmienna = 24

    elif zmienna == 25:
          zmienna = 25


    elif zmienna == 26:
          zmienna = 26

    elif zmienna == 27:
          zmienna = 27


    elif zmienna == 28:
          zmienna = 28

    elif zmienna == 29:
          zmienna = 29


    elif zmienna == 30:
          zmienna = 30


    elif zmienna == 31:

          zmienna = 31

    elif zmienna == 32:
          zmienna = 32


    elif zmienna == 33:
          zmienna = 33

    elif zmienna == 34:
          zmienna = 34


    elif zmienna == 35:
          zmienna = 35


    elif zmienna == 36:
          zmienna = 36


    elif zmienna == 37:
          zmienna = 37


    elif  zmienna== 38:
          zmienna = 38


    elif zmienna == 39:
          zmienna = 39


    elif zmienna == 40:
          zmienna = 40


    elif zmienna == 41:
          zmienna = 41

    elif zmienna == 42:

          zmienna = 42

    elif zmienna == 43:

          zmienna = 43

    elif zmienna == 44:

          zmienna = 44

    elif zmienna == 45:

          zmienna = 45

    elif zmienna == 46:

          zmienna = 46

    elif zmienna == 47:

          zmienna = 47

    elif zmienna == 48:

          zmienna = 48

    elif zmienna == 49:

          zmienna = 49

    elif zmienna == 50:


          zmienna = 50
    elif zmienna == 51:

          zmienna = 51

    elif zmienna == 52:
          zmienna = 52


    elif zmienna == 53:
          zmienna = 53


    elif zmienna == 54:

          zmienna = 54

    elif zmienna == 55:

          zmienna = 55

    elif zmienna == 56:
          zmienna = 56


    elif zmienna == 57:
          zmienna = 57



    elif zmienna == 58:
          zmienna = 58


    elif zmienna == 59:
          zmienna = 59

    elif zmienna == 60:
          zmienna =60
    elif zmienna == 61:
          zmienna = 61

    elif zmienna == 62:

          zmienna = 62
    elif zmienna == 63:

          zmienna = 63
    elif zmienna == 64:
          zmienna = 64

    elif zmienna == 65:
          zmienna = 65

    elif zmienna == 66:

          zmienna = 66
    elif zmienna== 67:

          zmienna = 67
    elif zmienna == 68:

          zmienna = 68
    elif zmienna == 69:

          zmienna = 69
    elif zmienna == 70:
          zmienna = 70

    elif zmienna == 71:
          zmienna = 71

    elif zmienna == 72:
          zmienna = 72

    elif zmienna == 73:
          zmienna = 73

    elif zmienna == 74:

          zmienna = 74
    elif zmienna == 75:

          zmienna = 75
    elif zmienna == 76:
          zmienna = 76

    elif zmienna == 77:
          zmienna = 77

    elif zmienna == 78:
          zmienna = 78
    elif zmienna == 79:
          zmienna = 79

    elif zmienna == 80:

          zmienna = 80


    elif zmienna == 81:
          zmienna = 81


    elif zmienna == 82:
          zmienna = 82

    elif zmienna == 83:
          zmienna = 83


    elif zmienna == 84:
          zmienna = 84

    elif zmienna == 85:

          zmienna = 85
    elif zmienna == 86:

          zmienna = 86
    elif zmienna == 87:

          zmienna = 87
    return zmienna

# %%
# Poprawna funkcja do sprawdzania lokalizacji zmiennej
def spr(zmienna):
    
    if len(zmienna) == 0:
        zmienna = 0
    elif zmienna == 1:
         zmienna = 1
            
    elif zmienna == 2:

        zmienna=2

    elif zmienna == 3:

        zmienna = 3

    elif zmienna == 4:

        zmienna = 4

    elif zmienna == 5:

        zmienna = 5

    elif zmienna == 6:
          zmienna = 6

    elif zmienna == 7:
          zmienna = 7
    elif zmienna == 8:
          zmienna = 8

    elif zmienna == 9:
          zmienna = 9

    elif zmienna == 10:
          zmienna = 10

    elif zmienna == 11:
          zmienna = 11

    elif zmienna== 12:
          zmienna = 12

    elif zmienna == 13:

          zmienna = 13
    elif zmienna == 14:
          zmienna = 14

    elif zmienna == 15:
          zmienna = 15

    elif zmienna == 16:
          zmienna = 16


    elif zmienna == 17:
          zmienna = 17

    elif zmienna == 18:
        zmienna = 18

    elif zmienna == 19:
          zmienna = 19


    elif zmienna == 20:
          zmienna = 20

    elif zmienna == 21:

          zmienna = 21

    elif zmienna == 22:
          zmienna = 22

    elif zmienna == 23:
          zmienna = 23


    elif zmienna == 24:
          zmienna = 24

    elif zmienna == 25:
          zmienna = 25


    elif zmienna == 26:
          zmienna = 26

    elif zmienna == 27:
          zmienna = 27


    elif zmienna == 28:
          zmienna = 28

    elif zmienna == 29:
          zmienna = 29


    elif zmienna == 30:
          zmienna = 30


    elif zmienna == 31:

          zmienna = 31

    elif zmienna == 32:
          zmienna = 32


    elif zmienna == 33:
          zmienna = 33

    elif zmienna == 34:
          zmienna = 34


    elif zmienna == 35:
          zmienna = 35


    elif zmienna == 36:
          zmienna = 36


    elif zmienna == 37:
          zmienna = 37


    elif  zmienna== 38:
          zmienna = 38


    elif zmienna == 39:
          zmienna = 39


    elif zmienna == 40:
          zmienna = 40


    elif zmienna == 41:
          zmienna = 41

    elif zmienna == 42:

          zmienna = 42

    elif zmienna == 43:

          zmienna = 43

    elif zmienna == 44:

          zmienna = 44

    elif zmienna == 45:

          zmienna = 45

    elif zmienna == 46:

          zmienna = 46

    elif zmienna == 47:

          zmienna = 47

    elif zmienna == 48:

          zmienna = 48

    elif zmienna == 49:

          zmienna = 49

    elif zmienna == 50:


          zmienna = 50
    elif zmienna == 51:

          zmienna = 51

    elif zmienna == 52:
          zmienna = 52


    elif zmienna == 53:
          zmienna = 53


    elif zmienna == 54:

          zmienna = 54

    elif zmienna == 55:

          zmienna = 55

    elif zmienna == 56:
          zmienna = 56


    elif zmienna == 57:
          zmienna = 57



    elif zmienna == 58:
          zmienna = 58


    elif zmienna == 59:
          zmienna = 59

    elif zmienna == 60:
          zmienna =60
    elif zmienna == 61:
          zmienna = 61

    elif zmienna == 62:

          zmienna = 62
    elif zmienna == 63:

          zmienna = 63
    elif zmienna == 64:
          zmienna = 64

    elif zmienna == 65:
          zmienna = 65

    elif zmienna == 66:

          zmienna = 66
    elif zmienna== 67:

          zmienna = 67
    elif zmienna == 68:

          zmienna = 68
    elif zmienna == 69:

          zmienna = 69
    elif zmienna == 70:
          zmienna = 70

    elif zmienna == 71:
          zmienna = 71

    elif zmienna == 72:
          zmienna = 72

    elif zmienna == 73:
          zmienna = 73

    elif zmienna == 74:

          zmienna = 74
    elif zmienna == 75:

          zmienna = 75
    elif zmienna == 76:
          zmienna = 76

    elif zmienna == 77:
          zmienna = 77

    elif zmienna == 78:
          zmienna = 78
    elif zmienna == 79:
          zmienna = 79

    elif zmienna == 80:

          zmienna = 80


    elif zmienna == 81:
          zmienna = 81


    elif zmienna == 82:
          zmienna = 82

    elif zmienna == 83:
          zmienna = 83


    elif zmienna == 84:
          zmienna = 84

    elif zmienna == 85:

          zmienna = 85
    elif zmienna == 86:

          zmienna = 86
    elif zmienna == 87:

          zmienna = 87
    return zmienna

# %%
def sprawdzenie_typu(alfabet,typ):
    try:
        if df[0].iloc[sprawdzenie(alfabet[0]),0] == typ:
            value = df[0].iloc[sprawdzenie(alfabet[0]),3]
        elif df[0].iloc[sprawdzenie(alfabet[1]),0] == typ:
            value = df[0].iloc[sprawdzenie(alfabet[1]),3]
        elif df[0].iloc[sprawdzenie(alfabet[2]),0] == typ:
            value = df[0].iloc[sprawdzenie(alfabet[2]),3]
        elif df[0].iloc[sprawdzenie(alfabet[3]),0] == typ:
            value = df[0].iloc[sprawdzenie(alfabet[3]),3]
        elif df[0].iloc[sprawdzenie(alfabet[4]),0] == typ:
            value = df[0].iloc[sprawdzenie(alfabet[4]),3]
        elif df[0].iloc[sprawdzenie(alfabet[5]),0] == typ:
            value = df[0].iloc[sprawdzenie(alfabet[5]),3]
        else:
            value = ""
    except IndexError: print("Błąd") 
    return value

# %%
def formula_puste(zmienna):
    try:
        if zmienna == df[0].iloc[0,1]:
            value = ""
        else:
            value = zmienna
    except: IndexError: ""
            
    return value

# %%
#DF2 do tworzenia pierwszego elementu w tabeli
df2 = pd.DataFrame({"Town / Commune":df[0].iloc[1,1],
'Address (street, house number)':df[0].iloc[2,1],
'District':df[0].iloc[3,1],
'Province (Voivodship)':df[0].iloc[4,1],
"The plot is a part of Special Economic Zone":df[0].iloc[5,1],
"Special Economic Zone":df[0].iloc[6,1],
"Website":formula_puste(df[0].iloc[7,1]),
"Link to My Maps":df[0].iloc[8,1],
"Max. available area (as one piece) [ha]":df[0].iloc[10,1],
'The shape of the site':df[0].iloc[10,1],
"Possibility for expansion (short description)":df[0].iloc[12,1],
'Approx. land price [PLN/m²] including 23% VAT':df[0].iloc[14,1],
'Owner':df[0].iloc[15,2],
'Owner area [ha]':df[0].iloc[16,2],
'Main owner type':df[0].iloc[17,2],
'Valid zoning plan':df[0].iloc[18,2],
"Link to the resolution":df[0].iloc[19,2],
"Zoning":df[0].iloc[20,2],
"Forms of support at the local level":df[0].iloc[21,2],
"Do you foresee a change in the Local Development Plan for Production buildings, warehouses?":df[0].iloc[22,2],
"Terms of acquisition - Sale":df[0].iloc[23,2],
"Terms of acquisition - Lease":df[0].iloc[24,2],
"Terms of acquisition - Perpetual usufruct":df[0].iloc[25,2],
"Present usage":df[0].iloc[27,2],
"Soil class":df[0].iloc[28,2],
"Area [ha]":df[0].iloc[29,2],
"Differences in land level [m]":df[0].iloc[30,2],
"Building height limit [m]":df[0].iloc[31,2],
"Building coverage [%]":df[0].iloc[32,2],
"Soil and underground water pollution":df[0].iloc[33,2],
"Underground water level [m]":df[0].iloc[34,2],
"Were geological research done":df[0].iloc[35,2],
"Risk of flooding or land slide":df[0].iloc[36,2],
"Underground obstacles":df[0].iloc[37,2],
"Ground and overhead obstacles":df[0].iloc[38,2],
"Ecological restrictions":df[0].iloc[39,2],
"Buildings / other constructions on site":df[0].iloc[40,2],
"Road width [m]":df[0].iloc[42,2],
"Road type":df[0].iloc[43,2],
"Road type":df[0].iloc[44,2],
"Road width [m]":df[0].iloc[45,2],
"Nearest motorway / express road / national road":df[0].iloc[46,2],
"Sea and river ports located up to 200 km":df[0].iloc[47,2],
"Railway line":df[0].iloc[48,2],
"Railway siding":df[0].iloc[49,2],
"Nearest international airport":df[0].iloc[50,2],
"Nearest province capital":df[0].iloc[51,2],
"Electricity":df[0].iloc[53,2],           
"Connection point (distance from boundary) [m] - Electricity":df[0].iloc[53,2],
"Voltage [kV]":df[0].iloc[54,2],
"Available capacity [MW]":df[0].iloc[55,2],
"Gas":df[0].iloc[56,2],                 
"Connection point (distance from boundary) [m] - Gas":df[0].iloc[56,2],
"Calorific value [MJ/Nm³]":df[0].iloc[57,2],
"Pipe diameter [mm]":df[0].iloc[58,2],
"Available capacity [Nm³/h]":df[0].iloc[59,2],
"Connection point (distance from boundary) [m] - Water for social purposes":df[0].iloc[60,2],
"Available capacity [m³/24h]":df[0].iloc[61,2],
"Water":df[0].iloc[53,2],                    
"Connection point (distance from boundary) [m] - Water":df[0].iloc[62,2],
"Available capacity [m³/24h] - Water":df[0].iloc[63,2],
"Connection point (distance from boundary) [m] - Sewage discharge":df[0].iloc[62,2],
"Available capacity [m³/24h] - Sewage discharge":df[0].iloc[63,2],               
"Connection point (distance from boundary) [m] - Telephone":df[0].iloc[66,2],
"Name, surname: - Offered by":df[0].iloc[68,2],
"Offered by-Phone:":df[0].iloc[69,2],
"Offered by-e-mail:":df[0].iloc[70,2],
"Name, surname - Contact Person":df[0].iloc[72,2],
"Contact person-Phone:":df[0].iloc[73,2],          
"Contact person-e-mail:":df[0].iloc[74,2],
"Offer link:": 'https://baza.paih.gov.pl/offer/detail/30-428'}, index=['1'])

# %%
#Lista do loopa

Lista_obiektów = ['14-272',
'04-517',
'26-109',
'26-108',
'26-111',
'18-236',
'18-237',
'18-232',
'22-312',
'22-206',
'22-215',
'22-379',
'22-386',
'22-378',
'22-302',
'22-190',
'22-370',
'22-369',
'22-371',
'22-306',
'22-282',
'22-408',
'22-373',
'04-315',
'12-397',
'02-493',
'04-431',
'24-524',
'24-523',
'24-522',
'24-520',
'24-394',
'22-301',
'06-249',
'18-257',
'16-183',
'30-378',
'16-291',
'30-538',
'04-433',
'04-432',
'04-246',
'04-434',
'24-490',
'16-192',
'14-288',
'18-226',
'30-722',
'12-400',
'12-391',
'30-607',
'30-671',
'30-672',
'10-184',
'30-673',
'30-449',
'30-730',
'04-363',
'04-216',
'04-211',
'32-332',
'30-729',
'12-291',
'08-217',
'22-266',
'02-234',
'02-244',
'12-394',
'30-534',
'04-244',
'08-216',
'18-117',
'30-725',
'30-728',
'26-177',
'30-547',
'32-341',
'32-399',
'06-225',
'24-506',
'24-510',
'04-466',
'12-289',
'30-675',
'14-279',
'06-207',
'12-398',
'20-162',
'06-245',
'24-479',
'10-407',
'30-712',
'30-458',
'10-277',
'20-151',
'10-410',
'30-289',
'32-394',
'32-384',
'32-395',
'22-374',
'30-720',
'18-74',
'30-414',
'30-486',
'30-609',
'04-264',
'12-217',
'02-385',
'16-149',
'02-442',
'06-201',
'02-238',
'30-708',
'04-423',
'22-271',
'04-266',
'16-132',
'24-529',
'24-528',
'16-145',
'16-343',
'16-146',
'02-495',
'16-194',
'16-310',
'02-422',
'32-261',
'30-723',
'06-246',
'30-724',
'14-152',
'14-285',
'26-146',
'26-165',
'26-166',
'26-171',
'22-486',
'18-261',
'06-239',
'22-485',
'14-275',
'02-502',
'10-328',
'14-284',
'18-262',
'06-149',
'06-140',
'32-428',
'30-295',
'32-427',
'10-371',
'04-427',
'04-300',
'30-707',
'06-248',
'30-706',
'30-702',
'04-437',
'22-477',
'30-380',
'30-681',
'10-258',
'22-298',
'10-362',
'06-191',
'30-668',
'10-374',
'10-230',
'26-176',
'26-167',
'04-193',
'22-479',
'16-331',
'16-333',
'16-332',
'16-334',
'16-335',
'18-103',
'18-102',
'18-191',
'12-360',
'10-266',
'10-237',
'10-236',
'04-454',
'04-359',
'14-215',
'14-201',
'26-135',
'22-232',
'04-425',
'20-105',
'14-220',
'32-343',
'28-353',
'02-370',
'12-361',
'18-196',
'18-199',
'04-444',
'18-200',
'02-492',
'30-719',
'06-244',
'06-176',
'22-294',
'12-387',
'32-424',
'02-494',
'32-154',
'28-355',
'28-292',
'28-288',
'24-513',
'06-139',
'04-459',
'16-248',
'24-369',
'04-254',
'28-341',
'02-435',
'10-292',
'06-242',
'30-428',
'06-128',
'14-216',
'14-189',
'32-422',
'32-423',
'30-367',
'12-338',
'14-135',
'30-718',
'14-278',
'12-175',
'04-218',
'04-298',
'32-411',
'32-426',
'06-241',
'06-205',
'12-390',
'12-384',
'10-347',
'10-344',
'06-240',
'12-154',
'10-337',
'14-186',
'06-197',
'10-153',
'24-500',
'12-216',
'30-383',
'30-382',
'32-323',
'08-211',
'24-519',
'12-176',
'32-412',
'32-416',
'14-190',
'22-295',
'02-360',
'32-420',
'12-309',
'32-413',
'02-466',
'16-129',
'16-200',
'32-408',
'16-266',
'16-136',
'02-197',
'02-198',
'02-478',
'02-477',
'32-410',
'30-551',
'30-713',
'32-418',
'32-409',
'32-407',
'32-417',
'18-253',
'24-385',
'12-268',
'12-266',
'12-267',
'06-171',
'10-186',
'08-115',
'30-601',
'28-354',
'30-678',
'06-236',
'24-271',
'32-271',
'32-262',
'32-258',
'32-345',
'32-348',
'32-381',
'14-129',
'32-272',
'32-273',
'32-268',
'32-346',
'04-175',
'04-157',
'28-333',
'12-158',
'10-404',
'14-158',
'20-82',
'24-386',
'04-332',
'04-323',
'30-655',
'04-333',
'04-334',
'30-618',
'18-250',
'06-234',
'18-224',
'06-238',
'04-314',
'04-515',
'06-134',
'06-103',
'32-421',
'30-651',
'32-400',
'30-697',
'10-220',
'06-123',
'06-237',
'10-150',
'16-276',
'24-512',
'06-113',
'06-164',
'06-111',
'30-709',
'12-282',
'02-431',
'24-517',
'24-514',
'28-155',
'10-160',
'10-154',
'30-491',
'30-606',
'06-209',
'12-200',
'30-704',
'06-227',
'06-226',
'06-228',
'18-146',
'06-235',
'04-255',
'10-401',
'10-402',
'24-502',
'30-549',
'10-397',
'24-515',
'24-516',
'30-300',
'30-434',
'30-557',
'30-439',
'30-440',
'30-438',
'30-475',
'30-433',
'30-701',
'30-705',
'02-394',
'30-619',
'30-587',
'30-700',
'30-699',
'30-649',
'30-564',
'06-232',
'30-698',
'30-512',
'30-613',
'10-351',
'30-309',
'30-302',
'30-688',
'24-503',
'20-176',
'10-298',
'30-696',
'30-695',
'30-694',
'30-693',
'30-692',
'30-679',
'30-691',
'30-689',
'30-680',
'12-386',
'04-509',
'12-167',
'30-446',
'06-229',
'06-230',
'08-174',
'30-687',
'16-144',
'30-686',
'30-667',
'16-222',
'02-506',
'02-504',
'30-567',
'06-185',
'14-124',
'32-292',
'06-200',
'28-309',
'24-467',
'20-71',
'06-181',
'16-260',
'02-503',
'16-280',
'02-412',
'10-400',
'02-226',
'16-141',
'02-438',
'02-436',
'06-199',
'16-127',
'30-617',
'30-614',
'12-199',
'10-149',
'32-108',
'04-513',
'04-508',
'04-477',
'02-505',
'06-219',
'24-505',
'06-175',
'06-160',
'06-179',
'06-155',
'10-339',
'10-355',
'32-380',
'04-511',
'24-438',
'30-665',
'10-357',
'10-180',
'18-248',
'32-378',
'10-361',
'04-297',
'04-362',
'04-262',
'26-104',
'18-124',
'18-131',
'14-218',
'14-184',
'14-217',
'06-162',
'22-407',
'16-301',
'30-499',
'20-131',
'18-239',
'24-246',
'06-222',
'16-242',
'24-470',
'30-670',
'06-220',
'16-290',
'12-378',
'22-345',
'22-319',
'22-321',
'22-320',
'22-322',
'06-218',
'30-442',
'30-444',
'12-354',
'06-214',
'06-213',
'12-160',
'06-217',
'02-388',
'16-229',
'16-224',
'30-368',
'06-215',
'06-216',
'30-507',
'14-198',
'14-271',
'12-383',
'12-382',
'28-335',
'30-419',
'30-460',
'30-307',
'18-246',
'12-194',
'12-352',
'30-459',
'12-303',
'12-353',
'04-351',
'14-138',
'26-161',
'26-139',
'26-150',
'26-120',
'26-123',
'26-160',
'26-124',
'26-116',
'26-121',
'30-666',
'06-183',
'06-110',
'06-150',
'06-178',
'02-469',
'06-204',
'04-480',
'30-284',
'30-272',
'30-271',
'18-245',
'12-351',
'14-185',
'02-290',
'10-398',
'06-208',
'10-171',
'10-178',
'30-336',
'30-353',
'04-484',
'04-200',
'30-334',
'30-510',
'12-310',
'16-246',
'32-368',
'32-365',
'30-350',
'14-154',
'16-170',
'16-164',
'16-171',
'16-168',
'16-199',
'16-201',
'32-330',
'28-57',
'04-460',
'08-113',
'32-373',
'02-300',
'16-240',
'18-76',
'18-147',
'18-142',
'18-167',
'18-140',
'18-112',
'18-202',
'18-148',
'06-163',
'18-121',
'18-149',
'02-287',
'10-238',
'10-234',
'10-235',
'32-405',
'20-145',
'20-147',
'14-263',
'06-165',
'28-178',
'04-231',
'04-232',
'04-229',
'04-256',
'04-224',
'04-348',
'12-376',
'12-302',
'12-243',
'12-242',
'14-274',
'10-395',
'10-394',
'18-218',
'18-230',
'18-231',
'18-219',
'18-210',
'18-211',
'12-275',
'04-457',
'16-277',
'28-289',
'28-217',
'28-130',
'28-303',
'28-290',
'02-314',
'24-351',
'24-327',
'24-354',
'24-346',
'22-193',
'22-231',
'22-412',
'22-410',
'30-466',
'30-413',
'30-521',
'16-347',
'18-82',
'18-80',
'18-79',
'04-394',
'04-197',
'04-393',
'04-419',
'04-215',
'28-227',
'30-415',
'22-280',
'12-375',
'28-181',
'28-320',
'08-107',
'12-343',
'24-469',
'24-274',
'30-417',
'16-147',
'02-232',
'18-243',
'18-217',
'30-490',
'30-363',
'30-365',
'30-364',
'06-127',
'06-125',
'06-126',
'06-122',
'16-324',
'32-111',
'32-113',
'32-110',
'04-196',
'12-315',
'10-271',
'30-660',
'30-662',
'04-449',
'02-214',
'22-478',
'02-355',
'16-270',
'08-201',
'08-208',
'08-207',
'08-206',
'08-205',
'08-196',
'08-199',
'08-203',
'12-203',
'04-443',
'08-202',
'02-449'
]

# %%
#Nowy kod sprawdzający lokalizację

for obiekt in Lista_obiektów:
    try:
        df = pd.read_html(f"https://baza.paih.gov.pl/offer/detail/{obiekt}")
        a = df[0][df[0]["Location.1"]=='Town / Commune:'].index.values
        b = df[0][df[0]["Location.1"]=='Address (street, house number):'].index.values
        c = df[0][df[0]["Location.1"]=='District:'].index.values
        d = df[0][df[0]["Location.1"]=='Province (Voivodship):'].index.values
        e = df[0][df[0]["Location.1"]=='The plot is a part of Special Economic Zone:'].index.values
        f = df[0][df[0]["Location.1"]=='Special Economic Zone:'].index.values
        g = df[0][df[0]["Location.1"]=='Website:'].index.values
        h = df[0][df[0]["Location.1"]=='Link to My Maps:'].index.values
        i = df[0][df[0]["Location.1"]=='Max. available area (as one piece) [ha]:'].index.values
        j = df[0][df[0]["Location.1"]=='The shape of the site:'].index.values
        k = df[0][df[0]["Location.1"]=='Possibility for expansion (short description):'].index.values
        l = df[0][df[0]["Location.1"]=='Approx. land price [PLN/m²] including 23% VAT:'].index.values
        m = df[0][df[0]["Location.2"]=='Owner'].index.values
        n = df[0][df[0]["Location.2"]=="Owner's area [ha]"].index.values
        o = df[0][df[0]["Location.2"]=='Main owner type'].index.values
        p = df[0][df[0]["Location.1"]=='Valid zoning plan:'].index.values
        r = df[0][df[0]["Location.1"]=='Link to the resolution:'].index.values
        s = df[0][df[0]["Location.1"]=='Zoning'].index.values
        t = df[0][df[0]["Location.1"]=='Forms of support at the local level:'].index.values
        u = df[0][df[0]["Location.1"]=='Do you foresee a change in the Local Development Plan for Production buildings, warehouses?:'].index.values
        w = df[0][df[0]["Location.2"]=='Sale'].index.values
        y = df[0][df[0]["Location.2"]=='Lease'].index.values
        z = df[0][df[0]["Location.2"]=='Perpetual usufruct'].index.values
        aa = df[0][df[0]["Location.1"]=='Present usage'].index.values
        ab = df[0][df[0]["Location.2"]=='Soil class'].index.values
        ac = df[0][df[0]["Location.2"]=='Area [ha]'].index.values
        ad = df[0][df[0]["Location.1"]=='Differences in land level [m]:'].index.values
        ae = df[0][df[0]["Location.1"]=='Building height limit [m]:'].index.values
        af = df[0][df[0]["Location.1"]=='Building coverage [%]:'].index.values
        ag = df[0][df[0]["Location.1"]=='Soil and underground water pollution:'].index.values
        ah = df[0][df[0]["Location.1"]=='Underground water level [m]:'].index.values
        ai = df[0][df[0]["Location.1"]=='Were geological research done:'].index.values
        aj = df[0][df[0]["Location.1"]=='Risk of flooding or land slide:'].index.values
        ak = df[0][df[0]["Location.1"]=='Underground obstacles:'].index.values
        al = df[0][df[0]["Location.1"]=='Ground and overhead obstacles:'].index.values
        am = df[0][df[0]["Location.1"]=='Ecological restrictions:'].index.values
        an = df[0][df[0]["Location.1"]=='Buildings / other constructions on site:'].index.values
        ao = df[0][df[0]["Location.2"]=='Road width [m]'].index.values
        ap = df[0][df[0]["Location.2"]=='Road type'].index.values
        ar = df[0][df[0]["Location.2"]=='Road type'].index.values
        ass = df[0][df[0]["Location.1"]=='Nearest motorway / express road / national road'].index.values
        at = df[0][df[0]["Location.1"]=='Sea and river ports located up to 200 km'].index.values
        au = df[0][df[0]["Location.1"]=='Railway line'].index.values
        aw = df[0][df[0]["Location.1"]=='Railway siding'].index.values
        ay = df[0][df[0]["Location.1"]=='Nearest international airport'].index.values
        az = df[0][df[0]["Location.1"]=='Nearest province capital'].index.values
        ba = df[0][df[0]["Location.2"]=='Connection point (distance from boundary) [m]'].index.values
        bb = df[0][df[0]["Location.2"]=='Voltage [kV]'].index.values
        bc = df[0][df[0]["Location.2"]=='Available capacity [MW]'].index.values
        bd = df[0][df[0]["Location.2"]=='Connection point (distance from boundary) [m]'].index.values
        be = df[0][df[0]["Location.2"]=='Calorific value [MJ/Nm³]'].index.values
        bf = df[0][df[0]["Location.2"]=='Pipe diameter [mm]'].index.values
        bg = df[0][df[0]["Location.2"]=='Available capacity [Nm³/h]'].index.values
        bh = df[0][df[0]["Location.2"]=='Connection point (distance from boundary) [m]'].index.values
        bi = df[0][df[0]["Location.2"]=='Available capacity [m³/24h]'].index.values
        bj = df[0][df[0]["Location.2"]=='Connection point (distance from boundary) [m]'].index.values
        bk = df[0][df[0]["Location.2"]=='Available capacity [m³/24h]'].index.values
        bl = df[0][df[0]["Location.2"]=='Connection point (distance from boundary) [m]'].index.values
        bm = df[0][df[0]["Location.1"]=='Name, surname:'].index.values
        bn = df[0][df[0]["Location.1"]=='Phone:'].index.values
        bo = df[0][df[0]["Location.1"]=='e-mail:'].index.values
        by = df[0][df[0]["Location"]=='Electricity'].index.values
        bz = df[0][df[0]["Location"]=='Gas'].index.values
        vb = df[0][df[0]["Location"]=='Water'].index.values
    
        df[0].iloc[0,3] = "No information"
        




        df1 = pd.DataFrame({"Town / Commune":formula_puste(df[0].iloc[spr(a),2]),
                'Address (street, house number)':formula_puste(df[0].iloc[spr(b),2]),
                'District':formula_puste(df[0].iloc[spr(c),2]),
                'Province (Voivodship)':formula_puste(df[0].iloc[spr(d),2]),
                "The plot is a part of Special Economic Zone":formula_puste(df[0].iloc[spr(e),2]),
                "Special Economic Zone":formula_puste(df[0].iloc[spr(f),2]),
                "Website":formula_puste(df[0].iloc[spr(g),2]),
                "Link to My Maps":formula_puste(df[0].iloc[spr(h),2]),
                "Max. available area (as one piece) [ha]":formula_puste(df[0].iloc[spr(i),2]),
                'The shape of the site':formula_puste(df[0].iloc[spr(j),2]),
                "Possibility for expansion (short description)":formula_puste(df[0].iloc[spr(k),2]),
                'Approx. land price [PLN/m²] including 23% VAT':formula_puste(df[0].iloc[spr(l),2]),
                'Owner':formula_puste(df[0].iloc[spr(m),3]),
                'Owner area [ha]':formula_puste(df[0].iloc[spr(n),3]),
                'Main owner type':formula_puste(df[0].iloc[spr(o),3]),
                'Valid zoning plan':formula_puste(df[0].iloc[spr(p),3]),
                "Link to the resolution":formula_puste(df[0].iloc[spr(r),3]),
                "Zoning":formula_puste(df[0].iloc[spr(s),3]),
                "Forms of support at the local level":formula_puste(df[0].iloc[spr(t),3]),
                "Do you foresee a change in the Local Development Plan for Production buildings, warehouses?":formula_puste(df[0].iloc[spr(u),3]),
                "Terms of acquisition - Sale":formula_puste(df[0].iloc[spr(w),3]),
                "Terms of acquisition - Lease":formula_puste(df[0].iloc[spr(y),3]),
                "Terms of acquisition - Perpetual usufruct":formula_puste(df[0].iloc[spr(z),3]),
                "Present usage":formula_puste(df[0].iloc[sprawdzenie(aa[0]),3]),
                "Soil class":formula_puste(df[0].iloc[sprawdzenie(ab[0]),3]),
                "Area [ha]":formula_puste(df[0].iloc[sprawdzenie(ac[0]),3]),
                "Differences in land level [m]":formula_puste(df[0].iloc[spr(ad),3]),
                "Building height limit [m]":formula_puste(df[0].iloc[spr(ae),3]),
                "Building coverage [%]":formula_puste(df[0].iloc[spr(af),3]),
                "Soil and underground water pollution":formula_puste(df[0].iloc[spr(ag),3]),
                "Underground water level [m]":formula_puste(df[0].iloc[spr(ah),3]),
                "Were geological research done":formula_puste(df[0].iloc[spr(ai),3]),
                "Risk of flooding or land slide":formula_puste(df[0].iloc[spr(aj),3]),
                "Underground obstacles":formula_puste(df[0].iloc[spr(ak),3]),
                "Ground and overhead obstacles":formula_puste(df[0].iloc[spr(al),3]),
                "Ecological restrictions":formula_puste(df[0].iloc[spr(am),3]),
                "Buildings / other constructions on site":formula_puste(df[0].iloc[spr(an),3]),
                "Road width [m]":formula_puste(df[0].iloc[spr(ao),3]),
                "Road type":formula_puste(df[0].iloc[spr(ap),3]),
                "Road type":formula_puste(df[0].iloc[spr(ar),3]),
                "Nearest motorway / express road / national road":formula_puste(df[0].iloc[sprawdzenie(ass[0]),3]),
                "Sea and river ports located up to 200 km":formula_puste(df[0].iloc[sprawdzenie(at[0]),3]),
                "Railway line":formula_puste(df[0].iloc[sprawdzenie(au[0]),3]),
                "Railway siding":formula_puste(df[0].iloc[sprawdzenie(aw[0]),3]),
                "Nearest international airport":formula_puste(df[0].iloc[sprawdzenie(ay[0]),3]),
                "Nearest province capital":formula_puste(df[0].iloc[sprawdzenie(az[0]),3]),
                "Electricity":formula_puste(df[0].iloc[by[1],1]),           
                "Connection point (distance from boundary) [m] - Electricity":formula_puste(sprawdzenie_typu(ba,'Electricity')), #Energy
                "Voltage [kV]":formula_puste(df[0].iloc[spr(bb),3]),    
                "Available capacity [MW]":formula_puste(df[0].iloc[spr(bc),3]), 
                "Gas":formula_puste(df[0].iloc[bz[1],1]) ,          
                "Connection point (distance from boundary) [m] - Gas":formula_puste(sprawdzenie_typu(ba,'Gas')), #Gas
                "Calorific value [MJ/Nm³]":formula_puste(df[0].iloc[spr(be),3]),       
                "Pipe diameter [mm]":formula_puste(df[0].iloc[spr(bf),3]),
                "Available capacity [Nm³/h]":formula_puste(df[0].iloc[spr(bg),3]),        
                "Connection point (distance from boundary) [m] - Water for social purposes":formula_puste(sprawdzenie_typu(ba,'Water for social purposes')),
                "Available capacity [m³/24h]":formula_puste(df[0].iloc[sprawdzenie(bi[0]),3]),
                "Water":formula_puste(df[0].iloc[vb[1],1]),
                "Connection point (distance from boundary) [m] - Water":formula_puste(sprawdzenie_typu(ba,'Water')),
                "Available capacity [m³/24h] - Water":formula_puste(df[0].iloc[sprawdzenie(bk[1]),3]),
                "Connection point (distance from boundary) [m] - Sewage discharge":formula_puste(sprawdzenie_typu(ba,'Sewage discharge')),
                "Available capacity [m³/24h] - Sewage discharge":formula_puste(df[0].iloc[sprawdzenie(bk[2]),3]),       
                "Connection point (distance from boundary) [m] - Telephone":formula_puste(sprawdzenie_typu(ba,'Telephone')),
                "Name, surname: - Offered by":formula_puste(df[0].iloc[sprawdzenie(bm[0]),3]),
                "Offered by-Phone:":formula_puste(df[0].iloc[sprawdzenie(bn[0]),3]),
                "Offered by-e-mail::":formula_puste(df[0].iloc[sprawdzenie(bo[0]),3]),
                "Name, surname - Contact Person":formula_puste(df[0].iloc[sprawdzenie(bm[1]),3]),
                "Contact person-Phone:":formula_puste(df[0].iloc[sprawdzenie(bn[1]),3]),           
                "Contact person-e-mail:":formula_puste(df[0].iloc[sprawdzenie(bo[1]),3]), 
                "Offer link:": f"https://baza.paih.gov.pl/offer/detail/{obiekt}"}, index=[obiekt])


        df2 = df2.append(df1)

  #      print(f'{obiekt} został dodany do listy')
    
    except Exception:
            pass
# Out:
# C:\Users\kawec\AppData\Local\Temp\ipykernel_9664\748093216.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(df1)
# C:\Users\kawec\AppData\Local\Temp\ipykernel_9664\748093216.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(df1)
# C:\Users\kawec\AppData\Local\Temp\ipykernel_9664\748093216.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(df1)
# C:\Users\kawec\AppData\Local\Temp\ipykernel_9664\748093216.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(df1)
# ...

# %%
df2
# Out:
#               Town / Commune   Address (street, house number)  \
# 1            Town / Commune:  Address (street, house number):
# 24-490  Siemianowice Śląskie                 Chemiczna Street
# 16-192      Kędzierzyn-Koźle                          Naftowa
# 24-490  Siemianowice Śląskie                 Chemiczna Street
# 16-192      Kędzierzyn-Koźle                          Naftowa
# ...                      ...                              ...
# 08-205                 Żagań                        Tomaszowo
# 08-196                 Żagań                        Tomaszowo
# 08-199                 Żagań                        Tomaszowo
# 12-203                Tarnów                  Piaskowa Avenue
# 08-202                 Żagań                        Tomaszowo
#
#                        District   Province (Voivodship)  \
# 1                     District:  Province (Voivodship):
# 24-490     Siemianowice Śląskie                 śląskie
# ...

# %% [markdown]
# ***Zadania***:
#
# - Zrobić by łapało wszystkie oferty. Z 600 złapał 300. Połowę omija.

# %%
#DF2 do tworzenia pierwszego elementu w tabeli
df2 = pd.DataFrame({"Name of production hall":df[0].iloc[1,1],
'Site name and plot numbers':df[0].iloc[2,1],
'Town / Commune':df[0].iloc[3,1],
'Address (street, house number)':df[0].iloc[4,1],
"District":df[0].iloc[5,1],
"Province (Voivodship)":df[0].iloc[6,1],
"The plot is a part of Special Economic Zone":df[0].iloc[7,1],
"Special Economic Zone":df[0].iloc[8,1],
"Technology/Industrial Park":df[0].iloc[10,1],
'Contact person':df[0].iloc[10,1],
"Name, surname":df[0].iloc[12,1],
'Phone':df[0].iloc[14,1],
'e-mail':df[0].iloc[15,2],
"Area [m²]":df[0].iloc[20,2],
"Year of construction":df[0].iloc[21,2],
"Height [m]":df[0].iloc[23,2],
"Number of storeys":df[0].iloc[24,2],
"Floor carrying capacity [kg/m²]":df[0].iloc[25,2],
"Floor car":df[0].iloc[27,2],
"Total area of land [m²]:":df[0].iloc[28,2],
"Transport links":df[0].iloc[29,2],
"Nearest motorway / express road / national road":df[0].iloc[30,2],
"Nearest province capital":df[0].iloc[31,2],
"Nearest international airport":df[0].iloc[32,2],
"Sea and river ports located up to 200 km":df[0].iloc[33,2],
"Railway line":df[0].iloc[34,2],
"Existing infrastructure":df[0].iloc[35,2],
"Electricity":df[0].iloc[36,2],
"Water for social purposes":df[0].iloc[37,2],
"Gas":df[0].iloc[38,2],
"Heating":df[0].iloc[39,2],
"Sewage discharge":df[0].iloc[40,2],
"Access road for trucks":df[0].iloc[42,2],
"Overhead cranes":df[0].iloc[43,2],
"Railway siding":df[0].iloc[44,2],
"Ownership:":df[0].iloc[44,2],
"Lease":df[0].iloc[44,2],
"Price in PLN, including hall and land":df[0].iloc[44,2],
"Forms of support at the local level":df[0].iloc[44,2],
"Owner(s)":df[0].iloc[40,2],
"Main owner type":df[0].iloc[41,2],
"Owner":df[0].iloc[43,2]},index=['1'])

# %%
  df = pd.read_html(f"https://baza.paih.gov.pl/offer/detail/{obiekt}")
        a = df[0][df[0]["Localization.1"]=='Name of production hall:'].index.values
        b = df[0][df[0]["Localization.2"]=='Site name and plot numbers'].index.values
        c = df[0][df[0]["Localization.2"]=='Town / Commune'].index.values
        d = df[0][df[0]["Localization.2"]=='Address (street, house number)'].index.values
        e = df[0][df[0]["Localization.2"]=='District'].index.values
        f = df[0][df[0]["Localization.2"]=='Province (Voivodship)'].index.values
        g = df[0][df[0]["Localization.2"]=='The plot is a part of Special Economic Zone'].index.values
        h = df[0][df[0]["Localization.2"]=='Special Economic Zone'].index.values
        i = df[0][df[0]["Localization.2"]=='Technology/Industrial Park'].index.values
        j = df[0][df[0]["Localization.2"]=='Contact person'].index.values
        k = df[0][df[0]["Localization.1"]=='Name, surname:'].index.values
        l = df[0][df[0]["Localization.1"]=='Phone:'].index.values
        m = df[0][df[0]["Localization.1"]=='e-mail:'].index.values
        n = df[0][df[0]["Localization.2"]=='Area [ha]'].index.values
        o = df[0][df[0]["Localization.2"]=='Year of construction'].index.values
        p = df[0][df[0]["Localization.2"]=='Height [m]'].index.values
        r = df[0][df[0]["Localization.2"]=='Number of storeys'].index.values    
        s = df[0][df[0]["Localization.2"]=='Floor carrying capacity [kg/m²]'].index.values
        t = df[0][df[0]["Localization.2"]=='Floor car'].index.values
        u = df[0][df[0]["Localization.1"]=='Total area of land [m²]:'].index.values
        w = df[0][df[0]["Localization.2"]=='Transport links'].index.values
        y = df[0][df[0]["Localization.1"]=='Nearest motorway / express road / national road'].index.values
        z = df[0][df[0]["Localization.1"]=='Nearest province capital'].index.values
        aa = df[0][df[0]["Localization.1"]=='Sea and river ports located up to 200 km'].index.values
        ab = df[0][df[0]["Localization.1"]=='Railway line'].index.values
        ac = df[0][df[0]["Localization.1"]=='Existing infrastructure'].index.values
        ad = df[0][df[0]["Localization"]=='Electricity'].index.values
        ae = df[0][df[0]["Localization"]=='Water for social purposes'].index.values
        af = df[0][df[0]["Localization"]=='Gas'].index.values
        ag = df[0][df[0]["Localization"]=='Heating'].index.values
        ah = df[0][df[0]["Localization"]=='Sewage discharge'].index.values
        ai = df[0][df[0]["Localization"]=='Access road for trucks'].index.values
        aj = df[0][df[0]["Localization"]=='Overhead cranes'].index.values
        ak = df[0][df[0]["Localization"]=='Railway siding'].index.values        
        al = df[0][df[0]["Localization.1"]=='Ownership:'].index.values
        am = df[0][df[0]["Localization.1"]=='Lease:'].index.values
        an = df[0][df[0]["Localization.1"]=='Price in PLN, including hall and land:'].index.values
        ao = df[0][df[0]["Localization.1"]=='Forms of support at the local level:'].index.values
        ap = df[0][df[0]["Localization.1"]=='Owner(s)'].index.values
        ar = df[0][df[0]["Localization.1"]=='Main owner type:'].index.values
        ass = df[0][df[0]["Localization.1"]=='Owner:'].index.values
        df[0].iloc[0,3] = "No information"
